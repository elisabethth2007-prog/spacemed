# %%
def sum_prod(a,b,c=1):
    return c*(a+b)

# %%
sum_prod(c=1,a=2,b=2)
# Out:
# 4

# %%
sum_prod(c=1,2,2) #SyntaxError: positional argument follows keyword argument
# Out:
#   Cell In[4], line 1
#     sum_prod(c=1,2,2)
#                     ^
# SyntaxError: positional argument follows keyword argument

# %%
name="Magnus"
age="old"

# %%
print(name, age, sep=" is ")
# Out:
# Magnus is old
